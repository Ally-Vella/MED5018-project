# %%
#导入包及数据
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_AR = pd.read_csv('../../data/by-age_split0000')

# %%
df_AR
# Out:
#            date location_key  new_confirmed_age_0  new_confirmed_age_1  \
# 0    0022-01-10           AR                  NaN                  NaN
# 1    0022-01-20           AR                  0.0                  NaN
# 2    0202-03-30           AR                  NaN                  NaN
# 3    0221-07-06           AR                  NaN                  NaN
# 4    1202-01-07           AR                  NaN                  NaN
# ..          ...          ...                  ...                  ...
# 942  2022-05-31           AR                156.0                411.0
# 943  2022-06-01           AR                135.0                364.0
# 944  2022-06-02           AR                107.0                289.0
# 945  2022-06-03           AR                 95.0                224.0
# 946  2022-06-04           AR                 22.0                 82.0
#
#      new_confirmed_age_2  new_confirmed_age_3  new_confirmed_age_4  \
# 0                    NaN                  NaN                  NaN
# 1                    0.0                  NaN                  0.0
# 2                    1.0                  NaN                  NaN
# 3                    0.0                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ..                   ...                  ...                  ...
# 942                784.0               1384.0               1285.0
# 943                784.0               1298.0               1241.0
# 944                648.0               1222.0               1109.0
# 945                525.0                911.0                893.0
# 946                185.0                378.0                363.0
#
#      new_confirmed_age_5  new_confirmed_age_6  new_confirmed_age_7  ...  \
# 0                    0.0                  NaN                  NaN  ...
# 1                    0.0                  NaN                  0.0  ...
# 2                    NaN                  NaN                  NaN  ...
# 3                    NaN                  NaN                  NaN  ...
# 4                    NaN                  NaN                  1.0  ...
# ..                   ...                  ...                  ...  ...
# 942                976.0                657.0                343.0  ...
# 943                897.0                654.0                339.0  ...
# 944                812.0                563.0                310.0  ...
# 945                626.0                468.0                237.0  ...
# 946                264.0                209.0                119.0  ...
#
#      age_bin_0  age_bin_1  age_bin_2  age_bin_3  age_bin_4  age_bin_5  \
# 0          0-9      10-19      20-29      30-39      40-49      50-59
# 1          0-9      10-19      20-29      30-39      40-49      50-59
# 2          0-9      10-19      20-29      30-39      40-49      50-59
# 3          0-9      10-19      20-29      30-39      40-49      50-59
# 4          0-9      10-19      20-29      30-39      40-49      50-59
# ..         ...        ...        ...        ...        ...        ...
# 942        0-9      10-19      20-29      30-39      40-49      50-59
# 943        0-9      10-19      20-29      30-39      40-49      50-59
# 944        0-9      10-19      20-29      30-39      40-49      50-59
# 945        0-9      10-19      20-29      30-39      40-49      50-59
# 946        0-9      10-19      20-29      30-39      40-49      50-59
#
#      age_bin_6  age_bin_7  age_bin_8  age_bin_9
# 0        60-69      70-79      80-89        90-
# 1        60-69      70-79      80-89        90-
# 2        60-69      70-79      80-89        90-
# 3        60-69      70-79      80-89        90-
# 4        60-69      70-79      80-89        90-
# ..         ...        ...        ...        ...
# 942      60-69      70-79      80-89        90-
# 943      60-69      70-79      80-89        90-
# 944      60-69      70-79      80-89        90-
# 945      60-69      70-79      80-89        90-
# 946      60-69      70-79      80-89        90-
#
# [947 rows x 152 columns]

# %%
columns  = df_AR.columns.values

# %%
df_BR_0 = pd.read_csv('../../data/by-age_split0386', names=columns)
df_BR_1 = pd.read_csv('../../data/by-age_split0387', names=columns)
df_BR = pd.concat([df_BR_0, df_BR_1])
df_BR = df_BR[df_BR.location_key == 'BR']

# %%
df_FR_0 = pd.read_csv('../../data/by-age_split3153', names=columns)
df_FR_1 = pd.read_csv('../../data/by-age_split3154', names=columns)
df_FR = pd.concat([df_FR_0, df_FR_1])
df_FR = df_FR[df_FR.location_key == 'FR']

# %%
df_US_0 = pd.read_csv('../../data/by-age_split3819', names=columns)
df_US_1 = pd.read_csv('../../data/by-age_split3820', names=columns)
df_US = pd.concat([df_US_0, df_US_1])
df_US = df_US[df_US.location_key == 'US']

# %%
df_FR
# Out:
#            date location_key  new_confirmed_age_0  new_confirmed_age_1  \
# 380  2020-05-13           FR                   13                   28
# 381  2020-05-14           FR                   19                   42
# 382  2020-05-15           FR                   16                   41
# 383  2020-05-16           FR                   10                   13
# 384  2020-05-17           FR                    6                    4
# ..          ...          ...                  ...                  ...
# 159  2022-05-10           FR                 2952                 3346
# 160  2022-05-11           FR                 2751                 3122
# 161  2022-05-12           FR                 2557                 2896
# 162  2022-05-13           FR                 2503                 2664
# 163  2022-05-14           FR                 1688                 2084
#
#      new_confirmed_age_2  new_confirmed_age_3  new_confirmed_age_4  \
# 380                  105                  109                  102
# 381                  116                  113                  121
# 382                  134                  131                  115
# 383                   37                   27                   39
# 384                   17                   12                   14
# ..                   ...                  ...                  ...
# 159                 4401                 5638                 5250
# 160                 4159                 5584                 5285
# 161                 3538                 4875                 4481
# 162                 3013                 4270                 4143
# 163                 2178                 3073                 3137
#
#      new_confirmed_age_5  new_confirmed_age_6  new_confirmed_age_7  ...  \
# 380                  117                   92                   90  ...
# 381                  129                   86                   84  ...
# 382                  128                   91                  104  ...
# 383                   32                   22                   27  ...
# 384                   18                   16                   16  ...
# ..                   ...                  ...                  ...  ...
# 159                 5311                 4868                 3869  ...
# 160                 5234                 4451                 3354  ...
# 161                 4645                 4081                 3137  ...
# 162                 4424                 3949                 3306  ...
# 163                 3318                 2806                 2092  ...
#
#      age_bin_0  age_bin_1  age_bin_2  age_bin_3  age_bin_4  age_bin_5  \
# 380        0-9      10-19      20-29      30-39      40-49      50-59
# 381        0-9      10-19      20-29      30-39      40-49      50-59
# 382        0-9      10-19      20-29      30-39      40-49      50-59
# 383        0-9      10-19      20-29      30-39      40-49      50-59
# 384        0-9      10-19      20-29      30-39      40-49      50-59
# ..         ...        ...        ...        ...        ...        ...
# 159        0-9      10-19      20-29      30-39      40-49      50-59
# 160        0-9      10-19      20-29      30-39      40-49      50-59
# 161        0-9      10-19      20-29      30-39      40-49      50-59
# 162        0-9      10-19      20-29      30-39      40-49      50-59
# 163        0-9      10-19      20-29      30-39      40-49      50-59
#
#      age_bin_6  age_bin_7  age_bin_8  age_bin_9
# 380      60-69      70-79      80-89        90-
# 381      60-69      70-79      80-89        90-
# 382      60-69      70-79      80-89        90-
# 383      60-69      70-79      80-89        90-
# 384      60-69      70-79      80-89        90-
# ..         ...        ...        ...        ...
# 159      60-69      70-79      80-89        90-
# 160      60-69      70-79      80-89        90-
# 161      60-69      70-79      80-89        90-
# 162      60-69      70-79      80-89        90-
# 163      60-69      70-79      80-89        90-
#
# [732 rows x 152 columns]

# %%
#有些国家地区数据不全，选取几个不同地区国家
age=['0-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80-89', '90-']

# %%
ar_cases=[df_AR['cumulative_confirmed_age_0'],df_AR['cumulative_confirmed_age_1'],df_AR['cumulative_confirmed_age_2'],df_AR['cumulative_confirmed_age_3'],df_AR['cumulative_confirmed_age_4'],df_AR['cumulative_confirmed_age_5'],df_AR['cumulative_confirmed_age_6'],df_AR['cumulative_confirmed_age_7'],df_AR['cumulative_confirmed_age_8'],df_AR['cumulative_confirmed_age_9']]
br_cases=[df_BR['cumulative_confirmed_age_0'],df_BR['cumulative_confirmed_age_1'],df_BR['cumulative_confirmed_age_2'],df_BR['cumulative_confirmed_age_3'],df_BR['cumulative_confirmed_age_4'],df_BR['cumulative_confirmed_age_5'],df_BR['cumulative_confirmed_age_6'],df_BR['cumulative_confirmed_age_7'],df_BR['cumulative_confirmed_age_8'],df_BR['cumulative_confirmed_age_9']]
fr_cases=[df_FR['cumulative_confirmed_age_0'],df_FR['cumulative_confirmed_age_1'],df_FR['cumulative_confirmed_age_2'],df_FR['cumulative_confirmed_age_3'],df_FR['cumulative_confirmed_age_4'],df_FR['cumulative_confirmed_age_5'],df_FR['cumulative_confirmed_age_6'],df_FR['cumulative_confirmed_age_7'],df_FR['cumulative_confirmed_age_8'],df_FR['cumulative_confirmed_age_9']]
# th_cases=[df_TH['cumulative_confirmed_age_0'],df_TH['cumulative_confirmed_age_1'],df_TH['cumulative_confirmed_age_2'],df_TH['cumulative_confirmed_age_3'],df_TH['cumulative_confirmed_age_4'],df_TH['cumulative_confirmed_age_5'],df_TH['cumulative_confirmed_age_6'],df_TH['cumulative_confirmed_age_7'],df_TH['cumulative_confirmed_age_8'],df_TH['cumulative_confirmed_age_9']]
us_cases=[df_US['cumulative_confirmed_age_0'],df_US['cumulative_confirmed_age_1'],df_US['cumulative_confirmed_age_2'],df_US['cumulative_confirmed_age_3'],df_US['cumulative_confirmed_age_4'],df_US['cumulative_confirmed_age_5'],df_US['cumulative_confirmed_age_6'],df_US['cumulative_confirmed_age_7'],df_US['cumulative_confirmed_age_8'],df_US['cumulative_confirmed_age_9']]
country=['AR','BR','FR','US']

# %%
df_AR.tail()
# Out:
#            date location_key  new_confirmed_age_0  new_confirmed_age_1  \
# 942  2022-05-31           AR                156.0                411.0
# 943  2022-06-01           AR                135.0                364.0
# 944  2022-06-02           AR                107.0                289.0
# 945  2022-06-03           AR                 95.0                224.0
# 946  2022-06-04           AR                 22.0                 82.0
#
#      new_confirmed_age_2  new_confirmed_age_3  new_confirmed_age_4  \
# 942                784.0               1384.0               1285.0
# 943                784.0               1298.0               1241.0
# 944                648.0               1222.0               1109.0
# 945                525.0                911.0                893.0
# 946                185.0                378.0                363.0
#
#      new_confirmed_age_5  new_confirmed_age_6  new_confirmed_age_7  ...  \
# 942                976.0                657.0                343.0  ...
# 943                897.0                654.0                339.0  ...
# 944                812.0                563.0                310.0  ...
# 945                626.0                468.0                237.0  ...
# 946                264.0                209.0                119.0  ...
#
#      age_bin_0  age_bin_1  age_bin_2  age_bin_3  age_bin_4  age_bin_5  \
# 942        0-9      10-19      20-29      30-39      40-49      50-59
# 943        0-9      10-19      20-29      30-39      40-49      50-59
# 944        0-9      10-19      20-29      30-39      40-49      50-59
# 945        0-9      10-19      20-29      30-39      40-49      50-59
# 946        0-9      10-19      20-29      30-39      40-49      50-59
#
#      age_bin_6  age_bin_7  age_bin_8  age_bin_9
# 942      60-69      70-79      80-89        90-
# 943      60-69      70-79      80-89        90-
# 944      60-69      70-79      80-89        90-
# 945      60-69      70-79      80-89        90-
# 946      60-69      70-79      80-89        90-
#
# [5 rows x 152 columns]

# %%
fig,ax = plt.subplots()
sns.barplot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/huajie/wsl_script/MED5018-project/code/direction2/full_data.ipynb Cell 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-18.04/home/huajie/wsl_script/MED5018-project/code/direction2/full_data.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> fig,ax = plt.subplots()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-18.04/home/huajie/wsl_script/MED5018-project/code/direction2/full_data.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> ax.bar(age,ar_cases,'bo-',label='AR')
#
# File ~/miniconda3/envs/scte/lib/python3.10/site-packages/matplotlib/__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/envs/scte/lib/python3.10/site-packages/matplotlib/axes/_axes.py:2345, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2342     if yerr is not None:
#    2343         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2345 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2346     # Make args iterable too.
#    2347     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2349 # Now that units have been converted, set the tick locations.
#    2350 if orientation == 'vertical':
#
# File <__array_function__ internals>:5, in broadcast_arrays(*args, **kwargs)
#
# File ~/miniconda3/envs/scte/lib/python3.10/site-packages/numpy/lib/stride_tricks.py:538, in broadcast_arrays(subok, *args)
#     531 # nditer is not used here to avoid the limit of 32 arrays.
#     532 # Otherwise, something like the following one-liner would suffice:
#     533 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     534 #                  order='C').itviews
#     536 args = [np.array(_m, copy=False, subok=subok) for _m in args]
# --> 538 shape = _broadcast_shape(*args)
#     540 if all(array.shape == shape for array in args):
#     541     # Common case where nothing needs to be broadcasted.
#     542     return args
#
# File ~/miniconda3/envs/scte/lib/python3.10/site-packages/numpy/lib/stride_tricks.py:420, in _broadcast_shape(*args)
#     415 """Returns the shape of the arrays that would result from broadcasting the
#     416 supplied arrays against each other.
#     417 """
#     418 # use the old-iterator because np.nditer does not handle size 0 arrays
#     419 # consistently
# --> 420 b = np.broadcast(*args[:32])
#     421 # unfortunately, it cannot handle 32 or more arguments directly
#     422 for pos in range(32, len(args), 31):
#     423     # ironically, np.broadcast does not properly handle np.broadcast
#     424     # objects (it treats them as scalars)
#     425     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
#不同年龄段的确诊人数
fig,ax = plt.subplots()
ax.plot(age,ar_cases,'bo-',label='AR')
ax.plot(age,br_cases,'p-',label='BR')
ax.plot(age,fr_cases,'rD-',label='FR')
# ax.plot(age,th_cases,'yo-',label='TH')
ax.plot(age,us_cases,'or-',label='US')
age_label = ['0-9', '10-19', '20-19', '30-39', '40-49', '50-59', '60-69', '70-79', '80-89', '90+']
ax.set_xticks(age)
ax.set_xticklabels(age_label,rotation=45)
ax.set_xlabel('age')
ax.set_ylabel('cases')

ax.grid(axis='x')
ax.legend(loc = 5, title = 'country')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/scte/lib/python3.10/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/miniconda3/envs/scte/lib/python3.10/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/miniconda3/envs/scte/lib/python3.10/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~/miniconda3/envs/scte/lib/python3.10/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/scte/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     405     deprecation_addendum = (
#     406         f"If any parameter follows {name!r}, they should be passed as "
#     407         f"keyword, not positionally.")
#     408     warn_deprecated(
#     409         since,
#     410         name=repr(name),
#    (...)
#     413                  else deprecation_addendum,
#     414         **kwargs)
# --> 415 return func(*inner_args, **inner_kwargs)
#
# File ~/miniconda3/envs/scte/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:540, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     490 @_check_savefig_extra_args
#     491 @_api.delete_parameter("3.5", "args")
#     492 def print_png(self, filename_or_obj, *args,
#     493               metadata=None, pil_kwargs=None):
#     494     """
#     495     Write the figure to a PNG file.
#     496
#    (...)
#     538         *metadata*, including the default 'Software' key.
#     539     """
# --> 540     FigureCanvasAgg.draw(self)
#     541     mpl.image.imsave(
#     542         filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/miniconda3/envs/scte/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:431, in FigureCanvasAgg.draw(self)
#     429 def draw(self):
#     430     # docstring inherited
# --> 431     self.renderer = self.get_renderer(cleared=True)
#     432     # Acquire a lock on the shared font cache.
#     433     with RendererAgg.lock, \
#     434          (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435           else nullcontext()):
#
# File ~/miniconda3/envs/scte/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:447, in FigureCanvasAgg.get_renderer(self, cleared)
#     444 reuse_renderer = (hasattr(self, "renderer")
#     445                   and getattr(self, "_lastKey", None) == key)
#     446 if not reuse_renderer:
# --> 447     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     448     self._lastKey = key
#     449 elif cleared:
#
# File ~/miniconda3/envs/scte/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:93, in RendererAgg.__init__(self, width, height, dpi)
#      91 self.width = width
#      92 self.height = height
# ---> 93 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      94 self._filter_renderers = []
#      96 self._update_methods()
#
# ValueError: Image size of 567x75633 pixels is too large. It must be less than 2^16 in each direction.

# %%
#将新冠肺炎情况数据文件和经济发展数据文件合并
df_AR=df[df['location_key']=='AR']
df_BR=df[df['location_key']=='BR']
df_FR=df[df['location_key']=='FR']
df_TH=df[df['location_key']=='TH']
df_CZ=df[df['location_key']=='CZ']
df_CO=df[df['location_key']=='CO']
df_HK=df[df['location_key']=='HK']
df_NZ=df[df['location_key']=='NZ']
df_MX=df[df['location_key']=='MX']
df1=pd.concat([df_AR,df_BR,df_FR,df_TH,df_CZ,df_CO,df_HK,df_NZ,df_MX],ignore_index=True)
df_e = pd.read_csv(r'C:\Users\24952\Desktop\wrq\Python\15\SARS-COV-2\economy.csv')
df_ARe=df_e[df_e['location']=='AR']
df_BRe=df_e[df_e['location']=='BR']
df_FRe=df_e[df_e['location']=='FR']
df_THe=df_e[df_e['location']=='TH']
df_CZe=df_e[df_e['location']=='US']
df_COe=df_e[df_e['location']=='CO']
df_HKe=df_e[df_e['location']=='HK']
df_NZe=df_e[df_e['location']=='NZ']
df_MXe=df_e[df_e['location']=='MX']
df1['cases'] = df1['cumulative_confirmed_age_0'] +df1['cumulative_confirmed_age_1']+df1['cumulative_confirmed_age_2']+df1['cumulative_confirmed_age_3']+df1['cumulative_confirmed_age_4']+df1['cumulative_confirmed_age_5']+df1['cumulative_confirmed_age_6']+df1['cumulative_confirmed_age_7']+df1['cumulative_confirmed_age_8']+df1['cumulative_confirmed_age_9']
df1['deaths']=df1['cumulative_deceased_age_0'] +df1['cumulative_deceased_age_1']+df1['cumulative_deceased_age_2']+df1['cumulative_deceased_age_3']+df1['cumulative_deceased_age_4']+df1['cumulative_deceased_age_5']+df1['cumulative_deceased_age_6']+df1['cumulative_deceased_age_7']+df1['cumulative_deceased_age_8']+df1['cumulative_deceased_age_9']
df1['death rate(%)']=(df1['deaths']/ df1['cases'])* 100
df2=pd.concat([df_ARe,df_BRe,df_FRe,df_THe,df_CZe,df_COe,df_HKe,df_NZe,df_MXe],ignore_index=True)
df3=pd.concat([df1,df2],axis=1)
df3
# Out:
#          date location_key  new_confirmed_age_0  new_confirmed_age_1  \
# 0  2022-06-04           AR                 22.0                 82.0
# 1  2022-09-09           BR                  0.0                  0.0
# 2  2022-05-14           FR               1688.0               2084.0
# 3  2021-08-11           TH               1287.0               1787.0
# 4  2022-09-14           CZ                115.0                164.0
# 5  2022-01-23           CO                  2.0                  5.0
# 6  2022-02-06           HK                 32.0                 20.0
# 7  2022-03-16           NZ               2380.0               3593.0
# 8  2022-09-14           MX                 35.0                 71.0
#
#    new_confirmed_age_2  new_confirmed_age_3  new_confirmed_age_4  \
# 0                185.0                378.0                363.0
# 1                  0.0                  0.0                  0.0
# 2               2178.0               3073.0               3137.0
# 3               4216.0               3936.0               3570.0
# 4                264.0                369.0                465.0
# 5                 17.0                 21.0                 19.0
# 6                 42.0                 86.0                 63.0
# 7               3707.0               3654.0               2870.0
# 8                142.0                131.0                108.0
#
#    new_confirmed_age_5  new_confirmed_age_6  new_confirmed_age_7  ...  \
# 0                264.0                209.0                119.0  ...
# 1                  0.0                  0.0                  0.0  ...
# 2               3318.0               2806.0               2092.0  ...
# 3               2553.0               1208.0                485.0  ...
# 4                394.0                348.0                351.0  ...
# 5                 14.0                  6.0                  4.0  ...
# 6                 47.0                 36.0                 11.0  ...
# 7               1828.0               1003.0                395.0  ...
# 8                 79.0                 40.0                 21.0  ...
#
#    age_bin_7  age_bin_8  age_bin_9       cases    deaths  death rate(%)  \
# 0      70-79      80-89        90-   9244998.0  128951.0       1.394819
# 1      70-79      80-89        90-  17262225.0  375838.0       2.177228
# 2      70-79      80-89        90-  29055825.0       NaN            NaN
# 3      70-79      80-89        90-    742211.0       NaN            NaN
# 4      70-79      80-89        90-   4067892.0   40932.0       1.006221
# 5      70-79      80-89        90-   5740179.0  155770.0       2.713678
# 6      70-79      80-89        90-     15347.0     216.0       1.407441
# 7      70-79      80-89        90-    438476.0       NaN            NaN
# 8      70-79      80-89        90-   2978564.0   23985.0       0.805254
#
#    location       gdp_usd  gdp_per_capita_usd  human_capital_index
# 0        AR  4.496630e+11             10006.0                0.611
# 1        BR  1.839760e+12              8717.0                0.560
# 2        FR  2.776650e+12             41300.0                0.765
# 3        TH  5.436500e+11              7808.0                0.604
# 4        US  2.137440e+13             65118.0                0.762
# 5        CO  3.238030e+11              6432.0                0.593
# 6        HK  3.660300e+11             48755.0                0.822
# 7        NZ  2.069290e+11             42084.0                0.767
# 8        MX  1.258290e+12              9863.0                0.607
#
# [9 rows x 159 columns]

# %%
#人均gdp和确诊人数的关系
sns.scatterplot(data = df3, x = 'gdp_per_capita_usd', y = 'cases', 
                hue = 'location_key')
# Out:
# <AxesSubplot:xlabel='gdp_per_capita_usd', ylabel='cases'>

# %%
#人均gdp和死亡率的关系
sns.scatterplot(data = df3, x = 'gdp_per_capita_usd', y = 'death rate(%)', 
                hue = 'location_key')
# Out:
# <AxesSubplot:xlabel='gdp_per_capita_usd', ylabel='death rate(%)'>

# %%
#将新冠肺炎情况数据文件和健康状况文件合并
df1['deaths']=df1['cumulative_deceased_age_0'] +df1['cumulative_deceased_age_1']+df1['cumulative_deceased_age_2']+df1['cumulative_deceased_age_3']+df1['cumulative_deceased_age_4']+df1['cumulative_deceased_age_5']+df1['cumulative_deceased_age_6']+df1['cumulative_deceased_age_7']+df1['cumulative_deceased_age_8']+df1['cumulative_deceased_age_9']
df1['death rate(%)']=(df1['deaths']/ df1['cases'])* 100
df_h = pd.read_csv(r'C:\Users\24952\Desktop\wrq\Python\15\SARS-COV-2\health.csv')
df_ARh=df_h[df_h['location']=='AR']
df_BRh=df_h[df_h['location']=='BR']
df_FRh=df_h[df_h['location']=='FR']
df_THh=df_h[df_h['location']=='TH']
df_CZh=df_h[df_h['location']=='US']
df_COh=df_h[df_h['location']=='CO']
df_HKh=df_h[df_h['location']=='HK']
df_NZh=df_h[df_h['location']=='NZ']
df_MXh=df_h[df_h['location']=='MX']
df4=pd.concat([df_ARh,df_BRh,df_FRh,df_THh,df_CZh,df_COh,df_HKh,df_NZh,df_MXh],ignore_index=True)
df5=pd.concat([df1,df4],axis=1)
df5
# Out:
#          date location_key  new_confirmed_age_0  new_confirmed_age_1  \
# 0  2022-06-04           AR                 22.0                 82.0
# 1  2022-09-09           BR                  0.0                  0.0
# 2  2022-05-14           FR               1688.0               2084.0
# 3  2021-08-11           TH               1287.0               1787.0
# 4  2022-09-14           CZ                115.0                164.0
# 5  2022-01-23           CO                  2.0                  5.0
# 6  2022-02-06           HK                 32.0                 20.0
# 7  2022-03-16           NZ               2380.0               3593.0
# 8  2022-09-14           MX                 35.0                 71.0
#
#    new_confirmed_age_2  new_confirmed_age_3  new_confirmed_age_4  \
# 0                185.0                378.0                363.0
# 1                  0.0                  0.0                  0.0
# 2               2178.0               3073.0               3137.0
# 3               4216.0               3936.0               3570.0
# 4                264.0                369.0                465.0
# 5                 17.0                 21.0                 19.0
# 6                 42.0                 86.0                 63.0
# 7               3707.0               3654.0               2870.0
# 8                142.0                131.0                108.0
#
#    new_confirmed_age_5  new_confirmed_age_6  new_confirmed_age_7  ...  \
# 0                264.0                209.0                119.0  ...
# 1                  0.0                  0.0                  0.0  ...
# 2               3318.0               2806.0               2092.0  ...
# 3               2553.0               1208.0                485.0  ...
# 4                394.0                348.0                351.0  ...
# 5                 14.0                  6.0                  4.0  ...
# 6                 47.0                 36.0                 11.0  ...
# 7               1828.0               1003.0                395.0  ...
# 8                 79.0                 40.0                 21.0  ...
#
#    infant_mortality_rate  adult_male_mortality_rate  \
# 0                    8.8                    147.086
# 1                   12.8                    188.528
# 2                    3.4                     95.352
# 3                    7.8                    186.853
# 4                    5.6                    139.141
# 5                   12.2                    151.616
# 6                    NaN                     61.901
# 7                    4.7                        NaN
# 8                   11.0                    184.379
#
#    adult_female_mortality_rate  pollution_mortality_rate  \
# 0                       79.483                      26.6
# 1                       91.421                      29.9
# 2                       48.187                       9.7
# 3                       77.992                      61.5
# 4                       81.935                      13.3
# 5                       77.999                      37.0
# 6                       33.104                       NaN
# 7                          NaN                       7.2
# 8                       95.815                      36.7
#
#    comorbidity_mortality_rate  hospital_beds_per_1000  nurses_per_1000  \
# 0                        15.8                     NaN           2.5996
# 1                        16.6                     NaN          10.1190
# 2                        10.6                     NaN          11.4707
# 3                        14.5                     NaN           2.7593
# 4                        14.6                     NaN          14.5480
# 5                        15.8                     NaN           1.3309
# 6                         NaN                     NaN              NaN
# 7                        10.1                     NaN          12.4482
# 8                        15.7                     1.5           2.3961
#
#    physicians_per_1000  health_expenditure_usd  \
# 0               3.9901             1324.603516
# 1               2.1643              928.799316
# 2               3.2672             4379.727051
# 3               0.8050              247.035110
# 4               2.6120            10246.138670
# 5               2.1848              459.197571
# 6                  NaN                     NaN
# 7               3.5898             3937.221924
# 8               2.3827              494.677643
#
#    out_of_pocket_health_expenditure_usd
# 0                            198.935944
# 1                            255.006439
# 2                            411.003204
# 3                             27.535921
# 4                           1126.349976
# 5                             74.887901
# 6                                   NaN
# 7                            534.559570
# 8                            204.219147
#
# [9 rows x 169 columns]

# %%
#吸烟率和死亡率的关系
sns.scatterplot(data = df5, x = 'smoking_prevalence', y = 'death rate(%)', 
                hue = 'location_key')
# Out:
# <AxesSubplot:xlabel='smoking_prevalence', ylabel='death rate(%)'>

# %%
#糖尿病患病率和死亡率的关系
sns.scatterplot(data = df5, x = 'diabetes_prevalence', y = 'death rate(%)', 
                hue = 'location_key')
# Out:
# <AxesSubplot:xlabel='diabetes_prevalence', ylabel='death rate(%)'>

# %%
#每千人中护士人数与死亡率的关系
sns.scatterplot(data = df5, x = 'nurses_per_1000', y = 'death rate(%)', 
                hue = 'location_key')
# Out:
# <AxesSubplot:xlabel='nurses_per_1000', ylabel='death rate(%)'>
